# %% [markdown]
# <a href="https://colab.research.google.com/github/arsh608/PAI-2024/blob/main/pai7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title example1
import matplotlib.pyplot as plt
a=[1,2,3,4]
b= [11,22,33,44]
plt.plot(a, b, color ='yellow', linestyle='--')
plt.show
#plt.plot(a,b)
#powerbi tablo
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Simport pandas as pd
import matplotlib.pyplot as plt

iris_df = pd.read_csv(r'Iris.csv')

species_counts = iris_df['Species'].value_counts()

plt.figure(figsize=(8, 5))
species_counts.plot(kind='bar', color=['blue', 'orange', 'green'])
plt.title('Number of Records for Each Iris Species')
plt.xlabel('Species')
plt.ylabel('Number of Records')
plt.xticks(rotation=0)
#plt.grid(axis='y')
#plt.tight_layout()
plt.show()
